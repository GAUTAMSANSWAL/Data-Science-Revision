# %%
import pandas as pd

# %%
pd.Series([71,84,98,82,74,64,95,82])
# Out:
# 0    71
# 1    84
# 2    98
# 3    82
# 4    74
# 5    64
# 6    95
# 7    82
# dtype: int64

# %%
pd.Series([71,84,98,82,74,64,95,82], index=["Gautam","Kashvi","Pinki","Yawar","Mehwish","Sneha","Aryan","Rishita"])
# Out:
# Gautam     71
# Kashvi     84
# Pinki      98
# Yawar      82
# Mehwish    74
# Sneha      64
# Aryan      95
# Rishita    82
# dtype: int64

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index         # Row labels
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns       # Column labels
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.index = ["a", "b", "c"]
df.columns = ["Name", "Age", "City"]

# %%
df
# Out:
#       Name  Age       City
# a    Alice   25      Delhi
# b      Bob   30     Mumbai
# c  Charlie   35  Bangalore
