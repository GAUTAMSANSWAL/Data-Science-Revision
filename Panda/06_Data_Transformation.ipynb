# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Open Source\Data-Science-Revision\Panda\movies_data.csv", encoding_errors = "replace")

# %%
df
# Out:
#                            Movie         Director  Running time  \
# 0                       13 Hours      Michael Bay           144
# 1                      16 Blocks   Richard Donner           102
# 2                       17 Again      Burr Steers           102
# 3                           1982     Tommy Oliver            90
# 4               2 Fast 2 Furious   John Singleton           107
# ...                          ...              ...           ...
# 3969                     Z Storm        David Lam            92
# 3970  Zack and Miri Make a Porno      Kevin Smith           101
# 3971                 Zero Effect      Jake Kasdan           116
# 3972                  Zombieland  Ruben Fleischer            88
# 3973                        Zulu     J�r?me Salle           110
#
#               Actor 1           Actor 2                    Actor 3      Genre  \
# 0       Toby Stephens  James Badge Dale            David Costabile     Action
# ...

# %%
df.sort_values('Release year')
# Out:
#                       Movie        Director  Running time  \
# 3471    The Broadway Melody  Harry Beaumont           100
# 2654          Hell's Angels   Howard Hughes            96
# 3272     She Done Him Wrong  Lowell Sherman            66
# 2000            42nd Street     Lloyd Bacon            89
# 1843  It Happened One Night     Frank Capra            65
# ...                     ...             ...           ...
# 1752           Hail Caesar!      Ethan Coen           106
# 1346            Zoolander 2     Ben Stiller           102
# 1567           The 5th Wave      J Blakeson           112
# 1560          Suicide Squad      David Ayer           123
# 1503          Pete's Dragon    David Lowery           102
#
#                   Actor 1             Actor 2             Actor 3      Genre  \
# 3471           Anita Page         Bessie Love        Charles King    Romance
# 2654          Jean Harlow        Marian Marsh          James Hall      Drama
# ...

# %%
df = df.sort_values(['Release year','IMDb score'], ascending = False)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                            Movie         Director  Running time  \
# 0           Kickboxer: Vengeance   John Stockwell            90
# 1                        Airlift       Raja Menon           130
# 2     Captain America: Civil War    Anthony Russo           147
# 3                       Deadpool       Tim Miller           108
# 4                     Mr. Church  Bruce Beresford           104
# ...                          ...              ...           ...
# 3969       It Happened One Night      Frank Capra            65
# 3970                 42nd Street      Lloyd Bacon            89
# 3971          She Done Him Wrong   Lowell Sherman            66
# 3972               Hell's Angels    Howard Hughes            96
# 3973         The Broadway Melody   Harry Beaumont           100
#
#                 Actor 1             Actor 2           Actor 3    Genre  \
# 0          Matthew Ziff          T.J. Storm        Sam Medina   Action
# ...

# %%
df['Rank'] = df['IMDb score'].rank(ascending = False)

# %%
df
# Out:
#                            Movie         Director  Running time  \
# 0           Kickboxer: Vengeance   John Stockwell            90
# 1                        Airlift       Raja Menon           130
# 2     Captain America: Civil War    Anthony Russo           147
# 3                       Deadpool       Tim Miller           108
# 4                     Mr. Church  Bruce Beresford           104
# ...                          ...              ...           ...
# 3969       It Happened One Night      Frank Capra            65
# 3970                 42nd Street      Lloyd Bacon            89
# 3971          She Done Him Wrong   Lowell Sherman            66
# 3972               Hell's Angels    Howard Hughes            96
# 3973         The Broadway Melody   Harry Beaumont           100
#
#                 Actor 1             Actor 2           Actor 3    Genre  \
# 0          Matthew Ziff          T.J. Storm        Sam Medina   Action
# ...

# %%
df.sort_values('Rank')
# Out:
#                                Movie              Director  Running time  \
# 3333        The Shawshank Redemption        Frank Darabont           142
# 3840                   The Godfather  Francis Ford Coppola           175
# 0               Kickboxer: Vengeance        John Stockwell            90
# 1295                 The Dark Knight     Christopher Nolan           152
# 3824          The Godfather: Part II  Francis Ford Coppola           220
# ...                              ...                   ...           ...
# 1636               Who's Your Caddy?      Don Michael Paul            93
# 1478                  Disaster Movie       Jason Friedberg            88
# 2170    Superbabies: Baby Geniuses 2             Bob Clark            88
# 761                       Foodfight!     Lawrence Kasanoff            91
# 937   Justin Bieber: Never Say Never            Jon M. Chu           115
#
#              Actor 1         Actor 2           Actor 3        Genre  \
# ...
