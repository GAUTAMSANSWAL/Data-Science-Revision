# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Open Source\Data-Science-Revision\Panda\movies_data.csv", encoding_errors = "replace")

# %%
df
# Out:
#                            Movie         Director  Running time  \
# 0                       13 Hours      Michael Bay           144
# 1                      16 Blocks   Richard Donner           102
# 2                       17 Again      Burr Steers           102
# 3                           1982     Tommy Oliver            90
# 4               2 Fast 2 Furious   John Singleton           107
# ...                          ...              ...           ...
# 3969                     Z Storm        David Lam            92
# 3970  Zack and Miri Make a Porno      Kevin Smith           101
# 3971                 Zero Effect      Jake Kasdan           116
# 3972                  Zombieland  Ruben Fleischer            88
# 3973                        Zulu     J�r?me Salle           110
#
#               Actor 1           Actor 2                    Actor 3      Genre  \
# 0       Toby Stephens  James Badge Dale            David Costabile     Action
# ...

# %%
df[['Director','Box Office','IMDb score']]
# Out:
#              Director  Box Office  IMDb score
# 0         Michael Bay    69400000         7.4
# 1      Richard Donner    65000000         6.6
# 2         Burr Steers   139000000         6.4
# 3        Tommy Oliver     2000000         7.1
# 4      John Singleton   236000000         5.9
# ...               ...         ...         ...
# 3969        David Lam    17000000         5.3
# 3970      Kevin Smith    42000000         6.6
# 3971      Jake Kasdan     2000000         7.0
# 3972  Ruben Fleischer   102000000         7.7
# 3973     J�r?me Salle     5000000         6.7
#
# [3974 rows x 3 columns]

# %%
# finds by row label
df.loc[1]
# Out:
# Movie                                       16 Blocks
# Director                               Richard Donner
# Running time                                      102
# Actor 1                                  Bruce Willis
# Actor 2                                   David Zayas
# Actor 3                                    Sasha Roiz
# Genre                                          Action
# Budget                                       52000000
# Box Office                                   65000000
# Actors Box Office %                             33.33
# Director Box Office %                            50.0
# Earnings                                     13000000
# Oscar and Golden Globes nominations                 0
# Oscar and Golden Globes awards                    0.0
# Release year                                     2006
# IMDb score                                        6.6
# Name: 1, dtype: object

# %%
# finds by row index
df.iloc[1]
# Out:
# Movie                                       16 Blocks
# Director                               Richard Donner
# Running time                                      102
# Actor 1                                  Bruce Willis
# Actor 2                                   David Zayas
# Actor 3                                    Sasha Roiz
# Genre                                          Action
# Budget                                       52000000
# Box Office                                   65000000
# Actors Box Office %                             33.33
# Director Box Office %                            50.0
# Earnings                                     13000000
# Oscar and Golden Globes nominations                 0
# Oscar and Golden Globes awards                    0.0
# Release year                                     2006
# IMDb score                                        6.6
# Name: 1, dtype: object

# %%
df.loc[4,'Box Office']
# Out:
# np.int64(236000000)

# %%
df.iloc[4,8]
# Out:
# np.int64(236000000)

# %%
df.loc[5:15, ['Movie','Director','Genre']]
# Out:
#                       Movie             Director   Genre
# 5                    2 Guns    Baltasar Korm�kur  Action
# 6                      2012      Roland Emmerich  Action
# 7                        21       Robert Luketic   Crime
# 8            22 Jump Street            Phil Lord  Action
# 9                27 Dresses        Anne Fletcher  Comedy
# 10              3 Backyards      Eric Mendelsohn   Drama
# 11         30 Days of Night          David Slade  Horror
# 12                      300          Zack Snyder  Action
# 13   300: Rise of an Empire           Noam Murro  Action
# 14  3000 Miles to Graceland  Demian Lichtenstein  Action
# 15                 47 Ronin          Carl Rinsch  Action

# %%
df.iloc[5:16,[0,1,6]]
# Out:
#                       Movie             Director   Genre
# 5                    2 Guns    Baltasar Korm�kur  Action
# 6                      2012      Roland Emmerich  Action
# 7                        21       Robert Luketic   Crime
# 8            22 Jump Street            Phil Lord  Action
# 9                27 Dresses        Anne Fletcher  Comedy
# 10              3 Backyards      Eric Mendelsohn   Drama
# 11         30 Days of Night          David Slade  Horror
# 12                      300          Zack Snyder  Action
# 13   300: Rise of an Empire           Noam Murro  Action
# 14  3000 Miles to Graceland  Demian Lichtenstein  Action
# 15                 47 Ronin          Carl Rinsch  Action

# %%
df.at[6,'Movie']
# Out:
# '2012'

# %%
df.iat[6,0]
# Out:
# '2012'

# %%
df[df['IMDb score']>9]
# Out:
#                          Movie              Director  Running time  \
# 1901  The Shawshank Redemption        Frank Darabont           142
# 1940             The Godfather  Francis Ford Coppola           175
# 2792      Kickboxer: Vengeance        John Stockwell            90
#
#              Actor 1         Actor 2        Actor 3   Genre    Budget  \
# 1901  Morgan Freeman  Jeffrey DeMunn     Bob Gunton   Crime  25000000
# 1940       Al Pacino   Marlon Brando  Robert Duvall   Crime   6000000
# 2792    Matthew Ziff      T.J. Storm     Sam Medina  Action  17000000
#
#       Box Office  Actors Box Office %  Director Box Office %   Earnings  \
# 1901    28000000                50.00                  50.00    3000000
# 1940   250000000                59.36                  72.72  244000000
# 2792     3000000                 0.00                   0.00  -14000000
#
#       Oscar and Golden Globes nominations  Oscar and Golden Globes awards  \
# ...

# %%
df[(df['IMDb score']>8) & (df['Earnings']>500_000_000)]
# Out:
#                                                   Movie            Director  \
# 995                               The Dark Knight Rises   Christopher Nolan
# 1402                                           Deadpool          Tim Miller
# 1684                            Guardians of the Galaxy          James Gunn
# 1690                                         Inside Out         Pete Docter
# 1721                                       The Avengers         Joss Whedon
# 1762                                      Jurassic Park    Steven Spielberg
# 1818                                      The Lion King        Roger Allers
# 1833                         Captain America: Civil War       Anthony Russo
# 1840                                       Finding Nemo      Andrew Stanton
# 1866                                       Interstellar   Christopher Nolan
# 1870  Pirates of the Caribbean: The Curse of the Bla...      Gore Verbinski
# ...
